# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import pandas as pd

from scipy import stats
from matplotlib import pyplot as plt

from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler


# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Merge 2018 Data Set to World Cup Data Set and Final Team Rankings

# %%
# View Matches dataset
fifa_all = pd.read_csv("WorldCupMatches.csv")

fifa_all.shape

display(fifa_all)
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0            France              4.0              1.0         Mexico
# 1               USA              3.0              0.0        Belgium
# 2        Yugoslavia              2.0              1.0         Brazil
# 3           Romania              3.0              1.0           Peru
# 4         Argentina              1.0              0.0         France
# ...             ...              ...              ...            ...
# 4567            NaN              NaN              NaN            NaN
# 4568            NaN              NaN              NaN            NaN
# 4569            NaN              NaN              NaN            NaN
# 4570            NaN              NaN              NaN            NaN
# 4571            NaN              NaN              NaN            NaN
#
#      Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                        4444.0                   3.0                   0.0
# 1                       18346.0                   2.0                   0.0
# 2                       24059.0                   2.0                   0.0
# 3                        2549.0                   1.0                   0.0
# 4                       23409.0                   0.0                   0.0
# ...             ...         ...                   ...                   ...
# 4567            NaN         NaN                   NaN                   NaN
# 4568            NaN         NaN                   NaN                   NaN
# 4569            NaN         NaN                   NaN                   NaN
# 4570            NaN         NaN                   NaN                   NaN
# 4571            NaN         NaN                   NaN                   NaN
#
#                      Referee               Assistant 1  \
# 0     LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1          MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2        TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3      WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4        REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# ...                      ...                       ...
# 4567                     NaN                       NaN
# 4568                     NaN                       NaN
# 4569                     NaN                       NaN
# 4570                     NaN                       NaN
# 4571                     NaN                       NaN
#
#                      Assistant 2  RoundID  MatchID Home Team Initials  \
# 0            REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1          WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2            BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3       MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4     RADULESCU Constantin (ROU)    201.0   1085.0                ARG
# ...                          ...      ...      ...                ...
# 4567                         NaN      NaN      NaN                NaN
# 4568                         NaN      NaN      NaN                NaN
# 4569                         NaN      NaN      NaN                NaN
# 4570                         NaN      NaN      NaN                NaN
# 4571                         NaN      NaN      NaN                NaN
#
#      Away Team Initials
# 0                   MEX
# 1                   BEL
# 2                   BRA
# 3                   PER
# 4                   FRA
# ...                 ...
# 4567                NaN
# 4568                NaN
# 4569                NaN
# 4570                NaN
# 4571                NaN
#
# [4572 rows x 20 columns]

# %% [markdown]
# ### Cleaning Matches Dataset

# %%
## Clean unnessary columns
fifa_clean = fifa_all.drop(["Datetime","Stadium", "City", "Attendance", "Referee", "Assistant 1", "Assistant 2", "MatchID"], axis=1)

## Remove trailing NAs
fifa_clean = fifa_clean.dropna(how='all')

# Change old team name of Cote d'Ivoire to Ivory Coast
fifa_clean[['Home Team Name', 'Away Team Name']] = fifa_clean[['Home Team Name', 'Away Team Name']].replace("C�te d'Ivoire", "Ivory Coast")

# Remove extra code chunk of " rn"> "
fifa_clean[['Home Team Name', 'Away Team Name']] = fifa_clean[['Home Team Name', 'Away Team Name']].replace({'rn">':''}, regex=True)

# Filter rows based on years from 1994 to 2014
newdf = (fifa_clean['Year'] >= 1994) & (fifa_clean['Year'] <= 2014)
  
# locate rows and access them using .loc() function
fifa_clean = fifa_clean.loc[newdf]

display(fifa_clean)
# Out:
#        Year                     Stage Home Team Name  Home Team Goals  \
# 464  1994.0                   Group C          Spain              2.0
# 465  1994.0                   Group C        Germany              1.0
# 466  1994.0                   Group A            USA              1.0
# 467  1994.0                   Group E          Italy              0.0
# 468  1994.0                   Group A       Colombia              1.0
# ..      ...                       ...            ...              ...
# 847  2014.0            Quarter-finals    Netherlands              0.0
# 848  2014.0               Semi-finals         Brazil              1.0
# 849  2014.0               Semi-finals    Netherlands              0.0
# 850  2014.0  Play-off for third place         Brazil              0.0
# 851  2014.0                     Final        Germany              1.0
#
#      Away Team Goals       Away Team Name  \
# 464              2.0       Korea Republic
# 465              0.0              Bolivia
# 466              1.0          Switzerland
# 467              1.0  Republic of Ireland
# 468              3.0              Romania
# ..               ...                  ...
# 847              0.0           Costa Rica
# 848              7.0              Germany
# 849              0.0            Argentina
# 850              3.0          Netherlands
# 851              0.0            Argentina
#
#                             Win conditions  Half-time Home Goals  \
# 464                                                          0.0
# 465                                                          0.0
# 466                                                          1.0
# 467                                                          0.0
# 468                                                          1.0
# ..                                     ...                   ...
# 847  Netherlands win on penalties (4 - 3)                    0.0
# 848                                                          0.0
# 849    Argentina win on penalties (2 - 4)                    0.0
# 850                                                          0.0
# 851          Germany win after extra time                    0.0
#
#      Half-time Away Goals   RoundID Home Team Initials Away Team Initials
# 464                   0.0     337.0                ESP                KOR
# 465                   0.0     337.0                GER                BOL
# 466                   1.0     337.0                USA                SUI
# 467                   1.0     337.0                ITA                IRL
# 468                   2.0     337.0                COL                ROU
# ..                    ...       ...                ...                ...
# 847                   0.0  255953.0                NED                CRC
# 848                   5.0  255955.0                BRA                GER
# 849                   0.0  255955.0                NED                ARG
# 850                   2.0  255957.0                BRA                NED
# 851                   0.0  255959.0                GER                ARG
#
# [388 rows x 12 columns]

# %% [markdown]
# ### Now we will add the 2018 Data Set and merge it

# %%
fifa_2018 = pd.read_csv("World_cup_2018_matches.csv")

# %%
fifa_2018
# Out:
#           Date        Stage      Home          Away  Home_goals  Away_goals  \
# 0   2018-06-14      Group-1    Russia  Saudi Arabia           5           0
# 1   2018-06-15      Group-1     Egypt       Uruguay           0           1
# 2   2018-06-15      Group-1   Morocco          Iran           0           1
# 3   2018-06-15      Group-1  Portugal         Spain           3           3
# 4   2018-06-16      Group-1    France     Australia           2           1
# ..         ...          ...       ...           ...         ...         ...
# 59  2018-07-07      QFinals    Russia       Croatia           2           2
# 60  2018-07-10      SFinals    France       Belgium           1           0
# 61  2018-07-11      SFinals   Croatia       England           2           1
# 62  2018-07-14  Third-Place   Belgium       England           2           0
# 63  2018-07-15        Final   Croatia        France           4           2
#
#     Home_shots  Home_shots_on_target  Home_possession  Home_fouls  ...  \
# 0           14                     7               38          22  ...
# 1            8                     3               41          12  ...
# 2           13                     3               68          22  ...
# 3            9                     3               33          12  ...
# 4           12                     5               55          16  ...
# ..         ...                   ...              ...         ...  ...
# 59          13                     5               35          25  ...
# 60          19                     5               36           6  ...
# 61          22                     7               56          23  ...
# 62          12                     4               42          11  ...
# 63           7                     6               34          13  ...
#
#     Away_offsides  Away_corners  Extra_time  Home_extra_goals  \
# 0               1             2         NaN               NaN
# 1               1             5         NaN               NaN
# 2               0             2         NaN               NaN
# 3               3             5         NaN               NaN
# 4               0             1         NaN               NaN
# ..            ...           ...         ...               ...
# 59              0             8           Y               1.0
# 60              1             5           N               NaN
# 61              3             4           Y               1.0
# 62              0             5           N               NaN
# 63              1             6           N               NaN
#
#     Away_extra_goals  Penalties  Home_PK_taken  Home_PK_made  Away_PK_taken  \
# 0                NaN        NaN            NaN           NaN            NaN
# 1                NaN        NaN            NaN           NaN            NaN
# 2                NaN        NaN            NaN           NaN            NaN
# 3                NaN        NaN            NaN           NaN            NaN
# 4                NaN        NaN            NaN           NaN            NaN
# ..               ...        ...            ...           ...            ...
# 59               1.0          Y            5.0           3.0            5.0
# 60               NaN          N            NaN           NaN            NaN
# 61               0.0          N            NaN           NaN            NaN
# 62               NaN          N            NaN           NaN            NaN
# 63               NaN          N            NaN           NaN            NaN
#
#     Away_PK_made
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 59           4.0
# 60           NaN
# 61           NaN
# 62           NaN
# 63           NaN
#
# [64 rows x 30 columns]

# %% [markdown]
# ### Team Rankings Scraped from fox news

# %%
Team_Rankings = pd.read_csv("final_team_rankings.csv")

# %%
Team_Rankings
# Out:
#     Unnamed: 0  Year                Host      Champion       Runner Up  \
# 0            0  2018              Russia        France         Croatia
# 1            1  2014              Brazil       Germany       Argentina
# 2            2  2010        South Africa         Spain     Netherlands
# 3            3  2006             Germany         Italy          France
# 4            4  2002  South Korea, Japan        Brazil         Germany
# 5            5  1998              France        France          Brazil
# 6            6  1994       United States        Brazil           Italy
# 7            7  1990               Italy  West Germany       Argentina
# 8            8  1986              Mexico     Argentina    West Germany
# 9            9  1982               Spain         Italy    West Germany
# 10          10  1978           Argentina     Argentina     Netherlands
# 11          11  1974        West Germany  West Germany     Netherlands
# 12          12  1970              Mexico        Brazil           Italy
# 13          13  1966             England       England    West Germany
# 14          14  1962               Chile        Brazil  Czechoslovakia
# 15          15  1958              Sweden        Brazil          Sweden
# 16          16  1954         Switzerland  West Germany         Hungary
# 17          17  1950              Brazil       Uruguay          Brazil
# 18          18  1938              France         Italy         Hungary
# 19          19  1934               Italy         Italy  Czechoslovakia
# 20          20  1930             Uruguay       Uruguay       Argentina
#
#       Third Place  Teams  Matches Played  Goals Scored  Avg Goals Per Game
# 0         Belgium     32              64           169                 2.6
# 1     Netherlands     32              64           171                 2.7
# 2         Germany     32              64           145                 2.3
# 3         Germany     32              64           147                 2.3
# 4          Turkey     32              64           161                 2.5
# 5         Croatia     32              64           171                 2.7
# 6          Sweden     24              52           141                 2.7
# 7           Italy     24              52           115                 2.2
# 8          France     24              52           132                 2.5
# 9          Poland     24              52           146                 2.8
# 10         Brazil     16              38           102                 2.7
# 11         Poland     16              38            97                 2.6
# 12   West Germany     16              32            95                 3.0
# 13       Portugal     16              32            89                 2.8
# 14          Chile     16              32            89                 2.8
# 15         France     16              35           126                 3.6
# 16        Austria     16              26           140                 5.4
# 17         Sweden     13              22            88                 4.0
# 18         Brazil     15              18            84                 4.7
# 19        Germany     16              17            70                 4.1
# 20  United States     13              16            70                 3.6

# %%
### Now we will first clean the 2018 Dataset by dropping values in it and then reordering the team rankings

# %%
fifa_2018.head(10)
# Out:
#          Date    Stage        Home          Away  Home_goals  Away_goals  \
# 0  2018-06-14  Group-1      Russia  Saudi Arabia           5           0
# 1  2018-06-15  Group-1       Egypt       Uruguay           0           1
# 2  2018-06-15  Group-1     Morocco          Iran           0           1
# 3  2018-06-15  Group-1    Portugal         Spain           3           3
# 4  2018-06-16  Group-1      France     Australia           2           1
# 5  2018-06-16  Group-1   Argentina       Iceland           1           1
# 6  2018-06-16  Group-1        Peru       Denmark           0           1
# 7  2018-06-16  Group-1     Croatia       Nigeria           2           0
# 8  2018-06-17  Group-1  Costa Rica        Serbia           0           1
# 9  2018-06-17  Group-1     Germany        Mexico           0           1
#
#    Home_shots  Home_shots_on_target  Home_possession  Home_fouls  ...  \
# 0          14                     7               38          22  ...
# 1           8                     3               41          12  ...
# 2          13                     3               68          22  ...
# 3           9                     3               33          12  ...
# 4          12                     5               55          16  ...
# 5          27                     7               78          10  ...
# 6          17                     6               54          10  ...
# 7          11                     2               55          20  ...
# 8          10                     3               53          18  ...
# 9          26                     9               67          10  ...
#
#    Away_offsides  Away_corners  Extra_time  Home_extra_goals  \
# 0              1             2         NaN               NaN
# 1              1             5         NaN               NaN
# 2              0             2         NaN               NaN
# 3              3             5         NaN               NaN
# 4              0             1         NaN               NaN
# 5              0             2         NaN               NaN
# 6              3             7         NaN               NaN
# 7              1             5         NaN               NaN
# 8              3             4         NaN               NaN
# 9              1             1         NaN               NaN
#
#    Away_extra_goals  Penalties  Home_PK_taken  Home_PK_made  Away_PK_taken  \
# 0               NaN        NaN            NaN           NaN            NaN
# 1               NaN        NaN            NaN           NaN            NaN
# 2               NaN        NaN            NaN           NaN            NaN
# 3               NaN        NaN            NaN           NaN            NaN
# 4               NaN        NaN            NaN           NaN            NaN
# 5               NaN        NaN            NaN           NaN            NaN
# 6               NaN        NaN            NaN           NaN            NaN
# 7               NaN        NaN            NaN           NaN            NaN
# 8               NaN        NaN            NaN           NaN            NaN
# 9               NaN        NaN            NaN           NaN            NaN
#
#    Away_PK_made
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
#
# [10 rows x 30 columns]

# %%
### We will now clean this dataset by first dropping all the unneeded columnsabs

# %%
fifa_2018_drop =fifa_2018.drop(['Extra_time', 'Home_extra_goals','Away_extra_goals','Penalties','Home_PK_taken','Away_PK_taken','Away_PK_made'],
                        axis = 1, inplace = True)

# %%
fifa_2018
# Out:
#           Date        Stage      Home          Away  Home_goals  Away_goals  \
# 0   2018-06-14      Group-1    Russia  Saudi Arabia           5           0
# 1   2018-06-15      Group-1     Egypt       Uruguay           0           1
# 2   2018-06-15      Group-1   Morocco          Iran           0           1
# 3   2018-06-15      Group-1  Portugal         Spain           3           3
# 4   2018-06-16      Group-1    France     Australia           2           1
# ..         ...          ...       ...           ...         ...         ...
# 59  2018-07-07      QFinals    Russia       Croatia           2           2
# 60  2018-07-10      SFinals    France       Belgium           1           0
# 61  2018-07-11      SFinals   Croatia       England           2           1
# 62  2018-07-14  Third-Place   Belgium       England           2           0
# 63  2018-07-15        Final   Croatia        France           4           2
#
#     Home_shots  Home_shots_on_target  Home_possession  Home_fouls  ...  \
# 0           14                     7               38          22  ...
# 1            8                     3               41          12  ...
# 2           13                     3               68          22  ...
# 3            9                     3               33          12  ...
# 4           12                     5               55          16  ...
# ..         ...                   ...              ...         ...  ...
# 59          13                     5               35          25  ...
# 60          19                     5               36           6  ...
# 61          22                     7               56          23  ...
# 62          12                     4               42          11  ...
# 63           7                     6               34          13  ...
#
#     Home_corners  Away_shots  Away_shots_on_target  Away_possession  \
# 0              6           6                     0               62
# 1              0          15                     5               59
# 2              5           9                     2               32
# 3              4          13                     6               67
# 4              5           6                     1               45
# ..           ...         ...                   ...              ...
# 59             6          18                     3               65
# 60             4           9                     3               64
# 61             8          11                     2               44
# 62             4          15                     6               58
# 63             2          14                     4               66
#
#     Away_fouls  Away_yellow  Away_red  Away_offsides  Away_corners  \
# 0           10            1         0              1             2
# 1            6            0         0              1             5
# 2           14            3         0              0             2
# 3           10            1         0              3             5
# 4           19            3         0              0             1
# ..         ...          ...       ...            ...           ...
# 59          18            4         0              0             8
# 60          16            3         0              1             5
# 61          14            1         0              3             4
# 62           4            2         0              0             5
# 63          13            1         0              1             6
#
#     Home_PK_made
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 59           3.0
# 60           NaN
# 61           NaN
# 62           NaN
# 63           NaN
#
# [64 rows x 23 columns]

# %%
fifa_2018_dr0p_columns =      fifa_2018.drop(columns=['Home_PK_made'])

# %%
fifa_2018_dr0p_columns.isna().sum()
# Out:
# Date                    0
# Stage                   0
# Home                    0
# Away                    0
# Home_goals              0
# Away_goals              0
# Home_shots              0
# Home_shots_on_target    0
# Home_possession         0
# Home_fouls              0
# Home_yellow             0
# Home_red                0
# Home_offsides           0
# Home_corners            0
# Away_shots              0
# Away_shots_on_target    0
# Away_possession         0
# Away_fouls              0
# Away_yellow             0
# Away_red                0
# Away_offsides           0
# Away_corners            0
# dtype: int64

# %%
#No null values in the 2018 data set so we can merge it with existing world cups but we might have to change the names.

# %%
##First we have to reorder team rankings and we will first need to drop a column

# %%
Team_Rankings
# Out:
#     Unnamed: 0  Year                Host      Champion       Runner Up  \
# 0            0  2018              Russia        France         Croatia
# 1            1  2014              Brazil       Germany       Argentina
# 2            2  2010        South Africa         Spain     Netherlands
# 3            3  2006             Germany         Italy          France
# 4            4  2002  South Korea, Japan        Brazil         Germany
# 5            5  1998              France        France          Brazil
# 6            6  1994       United States        Brazil           Italy
# 7            7  1990               Italy  West Germany       Argentina
# 8            8  1986              Mexico     Argentina    West Germany
# 9            9  1982               Spain         Italy    West Germany
# 10          10  1978           Argentina     Argentina     Netherlands
# 11          11  1974        West Germany  West Germany     Netherlands
# 12          12  1970              Mexico        Brazil           Italy
# 13          13  1966             England       England    West Germany
# 14          14  1962               Chile        Brazil  Czechoslovakia
# 15          15  1958              Sweden        Brazil          Sweden
# 16          16  1954         Switzerland  West Germany         Hungary
# 17          17  1950              Brazil       Uruguay          Brazil
# 18          18  1938              France         Italy         Hungary
# 19          19  1934               Italy         Italy  Czechoslovakia
# 20          20  1930             Uruguay       Uruguay       Argentina
#
#       Third Place  Teams  Matches Played  Goals Scored  Avg Goals Per Game
# 0         Belgium     32              64           169                 2.6
# 1     Netherlands     32              64           171                 2.7
# 2         Germany     32              64           145                 2.3
# 3         Germany     32              64           147                 2.3
# 4          Turkey     32              64           161                 2.5
# 5         Croatia     32              64           171                 2.7
# 6          Sweden     24              52           141                 2.7
# 7           Italy     24              52           115                 2.2
# 8          France     24              52           132                 2.5
# 9          Poland     24              52           146                 2.8
# 10         Brazil     16              38           102                 2.7
# 11         Poland     16              38            97                 2.6
# 12   West Germany     16              32            95                 3.0
# 13       Portugal     16              32            89                 2.8
# 14          Chile     16              32            89                 2.8
# 15         France     16              35           126                 3.6
# 16        Austria     16              26           140                 5.4
# 17         Sweden     13              22            88                 4.0
# 18         Brazil     15              18            84                 4.7
# 19        Germany     16              17            70                 4.1
# 20  United States     13              16            70                 3.6

# %%
final_team_rankings =Team_Rankings.sort_values("Year")

# %%
final_team_rankings
# Out:
#     Unnamed: 0  Year                Host      Champion       Runner Up  \
# 20          20  1930             Uruguay       Uruguay       Argentina
# 19          19  1934               Italy         Italy  Czechoslovakia
# 18          18  1938              France         Italy         Hungary
# 17          17  1950              Brazil       Uruguay          Brazil
# 16          16  1954         Switzerland  West Germany         Hungary
# 15          15  1958              Sweden        Brazil          Sweden
# 14          14  1962               Chile        Brazil  Czechoslovakia
# 13          13  1966             England       England    West Germany
# 12          12  1970              Mexico        Brazil           Italy
# 11          11  1974        West Germany  West Germany     Netherlands
# 10          10  1978           Argentina     Argentina     Netherlands
# 9            9  1982               Spain         Italy    West Germany
# 8            8  1986              Mexico     Argentina    West Germany
# 7            7  1990               Italy  West Germany       Argentina
# 6            6  1994       United States        Brazil           Italy
# 5            5  1998              France        France          Brazil
# 4            4  2002  South Korea, Japan        Brazil         Germany
# 3            3  2006             Germany         Italy          France
# 2            2  2010        South Africa         Spain     Netherlands
# 1            1  2014              Brazil       Germany       Argentina
# 0            0  2018              Russia        France         Croatia
#
#       Third Place  Teams  Matches Played  Goals Scored  Avg Goals Per Game
# 20  United States     13              16            70                 3.6
# 19        Germany     16              17            70                 4.1
# 18         Brazil     15              18            84                 4.7
# 17         Sweden     13              22            88                 4.0
# 16        Austria     16              26           140                 5.4
# 15         France     16              35           126                 3.6
# 14          Chile     16              32            89                 2.8
# 13       Portugal     16              32            89                 2.8
# 12   West Germany     16              32            95                 3.0
# 11         Poland     16              38            97                 2.6
# 10         Brazil     16              38           102                 2.7
# 9          Poland     24              52           146                 2.8
# 8          France     24              52           132                 2.5
# 7           Italy     24              52           115                 2.2
# 6          Sweden     24              52           141                 2.7
# 5         Croatia     32              64           171                 2.7
# 4          Turkey     32              64           161                 2.5
# 3         Germany     32              64           147                 2.3
# 2         Germany     32              64           145                 2.3
# 1     Netherlands     32              64           171                 2.7
# 0         Belgium     32              64           169                 2.6

# %%
##Now we will drop the unnamed column as it is not required.

# %%
final_rankings =  final_team_rankings.drop(columns=['Unnamed: 0'])

# %%
final_rankings
# Out:
#     Year                Host      Champion       Runner Up    Third Place  \
# 20  1930             Uruguay       Uruguay       Argentina  United States
# 19  1934               Italy         Italy  Czechoslovakia        Germany
# 18  1938              France         Italy         Hungary         Brazil
# 17  1950              Brazil       Uruguay          Brazil         Sweden
# 16  1954         Switzerland  West Germany         Hungary        Austria
# 15  1958              Sweden        Brazil          Sweden         France
# 14  1962               Chile        Brazil  Czechoslovakia          Chile
# 13  1966             England       England    West Germany       Portugal
# 12  1970              Mexico        Brazil           Italy   West Germany
# 11  1974        West Germany  West Germany     Netherlands         Poland
# 10  1978           Argentina     Argentina     Netherlands         Brazil
# 9   1982               Spain         Italy    West Germany         Poland
# 8   1986              Mexico     Argentina    West Germany         France
# 7   1990               Italy  West Germany       Argentina          Italy
# 6   1994       United States        Brazil           Italy         Sweden
# 5   1998              France        France          Brazil        Croatia
# 4   2002  South Korea, Japan        Brazil         Germany         Turkey
# 3   2006             Germany         Italy          France        Germany
# 2   2010        South Africa         Spain     Netherlands        Germany
# 1   2014              Brazil       Germany       Argentina    Netherlands
# 0   2018              Russia        France         Croatia        Belgium
#
#     Teams  Matches Played  Goals Scored  Avg Goals Per Game
# 20     13              16            70                 3.6
# 19     16              17            70                 4.1
# 18     15              18            84                 4.7
# 17     13              22            88                 4.0
# 16     16              26           140                 5.4
# 15     16              35           126                 3.6
# 14     16              32            89                 2.8
# 13     16              32            89                 2.8
# 12     16              32            95                 3.0
# 11     16              38            97                 2.6
# 10     16              38           102                 2.7
# 9      24              52           146                 2.8
# 8      24              52           132                 2.5
# 7      24              52           115                 2.2
# 6      24              52           141                 2.7
# 5      32              64           171                 2.7
# 4      32              64           161                 2.5
# 3      32              64           147                 2.3
# 2      32              64           145                 2.3
# 1      32              64           171                 2.7
# 0      32              64           169                 2.6

# %%
#Now we need to merge this data set with original data set but before that rename the column names for the 2018 data set.

# %%
fifa_cup_2018 = fifa_2018_dr0p_columns

# %%
fifa_cup_2018
# Out:
#           Date        Stage      Home          Away  Home_goals  Away_goals  \
# 0   2018-06-14      Group-1    Russia  Saudi Arabia           5           0
# 1   2018-06-15      Group-1     Egypt       Uruguay           0           1
# 2   2018-06-15      Group-1   Morocco          Iran           0           1
# 3   2018-06-15      Group-1  Portugal         Spain           3           3
# 4   2018-06-16      Group-1    France     Australia           2           1
# ..         ...          ...       ...           ...         ...         ...
# 59  2018-07-07      QFinals    Russia       Croatia           2           2
# 60  2018-07-10      SFinals    France       Belgium           1           0
# 61  2018-07-11      SFinals   Croatia       England           2           1
# 62  2018-07-14  Third-Place   Belgium       England           2           0
# 63  2018-07-15        Final   Croatia        France           4           2
#
#     Home_shots  Home_shots_on_target  Home_possession  Home_fouls  ...  \
# 0           14                     7               38          22  ...
# 1            8                     3               41          12  ...
# 2           13                     3               68          22  ...
# 3            9                     3               33          12  ...
# 4           12                     5               55          16  ...
# ..         ...                   ...              ...         ...  ...
# 59          13                     5               35          25  ...
# 60          19                     5               36           6  ...
# 61          22                     7               56          23  ...
# 62          12                     4               42          11  ...
# 63           7                     6               34          13  ...
#
#     Home_offsides  Home_corners  Away_shots  Away_shots_on_target  \
# 0               3             6           6                     0
# 1               1             0          15                     5
# 2               0             5           9                     2
# 3               1             4          13                     6
# 4               0             5           6                     1
# ..            ...           ...         ...                   ...
# 59              1             6          18                     3
# 60              1             4           9                     3
# 61              1             8          11                     2
# 62              1             4          15                     6
# 63              1             2          14                     4
#
#     Away_possession  Away_fouls  Away_yellow  Away_red  Away_offsides  \
# 0                62          10            1         0              1
# 1                59           6            0         0              1
# 2                32          14            3         0              0
# 3                67          10            1         0              3
# 4                45          19            3         0              0
# ..              ...         ...          ...       ...            ...
# 59               65          18            4         0              0
# 60               64          16            3         0              1
# 61               44          14            1         0              3
# 62               58           4            2         0              0
# 63               66          13            1         0              1
#
#     Away_corners
# 0              2
# 1              5
# 2              2
# 3              5
# 4              1
# ..           ...
# 59             8
# 60             5
# 61             4
# 62             5
# 63             6
#
# [64 rows x 22 columns]

# %%
fifa_clean
# Out:
#        Year                     Stage Home Team Name  Home Team Goals  \
# 464  1994.0                   Group C          Spain              2.0
# 465  1994.0                   Group C        Germany              1.0
# 466  1994.0                   Group A            USA              1.0
# 467  1994.0                   Group E          Italy              0.0
# 468  1994.0                   Group A       Colombia              1.0
# ..      ...                       ...            ...              ...
# 847  2014.0            Quarter-finals    Netherlands              0.0
# 848  2014.0               Semi-finals         Brazil              1.0
# 849  2014.0               Semi-finals    Netherlands              0.0
# 850  2014.0  Play-off for third place         Brazil              0.0
# 851  2014.0                     Final        Germany              1.0
#
#      Away Team Goals       Away Team Name  \
# 464              2.0       Korea Republic
# 465              0.0              Bolivia
# 466              1.0          Switzerland
# 467              1.0  Republic of Ireland
# 468              3.0              Romania
# ..               ...                  ...
# 847              0.0           Costa Rica
# 848              7.0              Germany
# 849              0.0            Argentina
# 850              3.0          Netherlands
# 851              0.0            Argentina
#
#                             Win conditions  Half-time Home Goals  \
# 464                                                          0.0
# 465                                                          0.0
# 466                                                          1.0
# 467                                                          0.0
# 468                                                          1.0
# ..                                     ...                   ...
# 847  Netherlands win on penalties (4 - 3)                    0.0
# 848                                                          0.0
# 849    Argentina win on penalties (2 - 4)                    0.0
# 850                                                          0.0
# 851          Germany win after extra time                    0.0
#
#      Half-time Away Goals   RoundID Home Team Initials Away Team Initials
# 464                   0.0     337.0                ESP                KOR
# 465                   0.0     337.0                GER                BOL
# 466                   1.0     337.0                USA                SUI
# 467                   1.0     337.0                ITA                IRL
# 468                   2.0     337.0                COL                ROU
# ..                    ...       ...                ...                ...
# 847                   0.0  255953.0                NED                CRC
# 848                   5.0  255955.0                BRA                GER
# 849                   0.0  255955.0                NED                ARG
# 850                   2.0  255957.0                BRA                NED
# 851                   0.0  255959.0                GER                ARG
#
# [388 rows x 12 columns]

# %%
### Rankings is applied to the data set. Now rename the columns for the data set of 20i8 then append it.

# %%
fifa_cup_2018.rename(columns={'Date': 'Year',
                   'Home': 'Home Team Name','Away':'Away Team Goals','Home_goals':'Home Team Goals','Away_goals':'Away Team Goals'},
          inplace=True)
# Make sure you set inplace to True if you want the change
# to be applied to the dataframe

# %%
fifa_cup_2018
# Out:
#           Year        Stage Home Team Name  Away Team Goals  Home Team Goals  \
# 0   2018-06-14      Group-1         Russia     Saudi Arabia                5
# 1   2018-06-15      Group-1          Egypt          Uruguay                0
# 2   2018-06-15      Group-1        Morocco             Iran                0
# 3   2018-06-15      Group-1       Portugal            Spain                3
# 4   2018-06-16      Group-1         France        Australia                2
# ..         ...          ...            ...              ...              ...
# 59  2018-07-07      QFinals         Russia          Croatia                2
# 60  2018-07-10      SFinals         France          Belgium                1
# 61  2018-07-11      SFinals        Croatia          England                2
# 62  2018-07-14  Third-Place        Belgium          England                2
# 63  2018-07-15        Final        Croatia           France                4
#
#     Away Team Goals  Home_shots  Home_shots_on_target  Home_possession  \
# 0                 0          14                     7               38
# 1                 1           8                     3               41
# 2                 1          13                     3               68
# 3                 3           9                     3               33
# 4                 1          12                     5               55
# ..              ...         ...                   ...              ...
# 59                2          13                     5               35
# 60                0          19                     5               36
# 61                1          22                     7               56
# 62                0          12                     4               42
# 63                2           7                     6               34
#
#     Home_fouls  ...  Home_offsides  Home_corners  Away_shots  \
# 0           22  ...              3             6           6
# 1           12  ...              1             0          15
# 2           22  ...              0             5           9
# 3           12  ...              1             4          13
# 4           16  ...              0             5           6
# ..         ...  ...            ...           ...         ...
# 59          25  ...              1             6          18
# 60           6  ...              1             4           9
# 61          23  ...              1             8          11
# 62          11  ...              1             4          15
# 63          13  ...              1             2          14
#
#     Away_shots_on_target  Away_possession  Away_fouls  Away_yellow  Away_red  \
# 0                      0               62          10            1         0
# 1                      5               59           6            0         0
# 2                      2               32          14            3         0
# 3                      6               67          10            1         0
# 4                      1               45          19            3         0
# ..                   ...              ...         ...          ...       ...
# 59                     3               65          18            4         0
# 60                     3               64          16            3         0
# 61                     2               44          14            1         0
# 62                     6               58           4            2         0
# 63                     4               66          13            1         0
#
#     Away_offsides  Away_corners
# 0               1             2
# 1               1             5
# 2               0             2
# 3               3             5
# 4               0             1
# ..            ...           ...
# 59              0             8
# 60              1             5
# 61              3             4
# 62              0             5
# 63              1             6
#
# [64 rows x 22 columns]

# %%
### Now we merge all data sets

# %%
### Visualisations and Insights for the data set.

# %%
gold = fifa_clean["Winner"]
silver = fifa_clean["Runners-Up"]
bronze = fifa_clean["Third"]

gold_count = pd.DataFrame.from_dict(gold.value_counts())
silver_count = pd.DataFrame.from_dict(gold.value_counts())
bronze_count = pd.DataFrame.from_dict(gold.value_counts())
podium_count = gold_count.join(silver_count, how="outer").join(bronze_count, how='outer')
podium_count = podium_count.fillna(0)
podium_count.columns = ['Winner','Second','Third']
podium_count = podium_count.astype('int64')
podium_count = podium_count.sort_values(by=['Winner','Second','Third'], ascending=False)
podium_count.plot(y=['Winner','Second','Third'], kind="bar", color=['gold','silver','brown'], figsize=(15,6), fontsize=14,
                 width=0.8, align='centre')
plt.xlabel('Countries')
plt.ylabel('Number of podium')
plt.title('Number of podium by country ')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Winner'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-894ce9d1b1cd> in <module>
# ----> 1 gold = fifa_clean["Winner"]
#       2 silver = fifa_clean["Runners-Up"]
#       3 bronze = fifa_clean["Third"]
#       4
#       5 gold_count = pd.DataFrame.from_dict(gold.value_counts())
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Winner'
