# %% [markdown]
# # Is the FIFA World Cup Draw Truely Random?

# %%
#Here we import the libraries we will be using for this project.

import pandas as pd
import numpy as np
import math
import seaborn as sns
import pandas as pd

from scipy import stats
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
#Here we load the data set and store in the variable covid_19_EI
#We use the pandas library to read the data set
fifaRanks = pd.read_csv("fifa_ranking-2020-12-10.csv")

# %% [markdown]
# ##  1 Undestanding the data

# %%
print('Numpy: ', np.__version__)
print('Pandas: ', pd.__version__)
# Out:
# Numpy:  1.20.3
# Pandas:  1.2.4

# %%
fifaRanks
# Out:
#             id  rank          country_full country_abrv  total_points  \
# 0        43885   104             Swaziland          SWZ            10
# 1        43972    42                Turkey          TUR            31
# 2        43952    43      Northern Ireland          NIR            31
# 3        43945    44               Finland          FIN            31
# 4        43976    45             Australia          AUS            29
# ...        ...   ...                   ...          ...           ...
# 62419    43840    74  United Arab Emirates          UAE          1326
# 62420    43812    75              China PR          CHN          1323
# 62421  1930407    76               Curaçao          CUW          1313
# 62422    43901    51            Costa Rica          CRC          1427
# 62423    43966   210            San Marino          SMR           810
#
#        previous_points  rank_change confederation   rank_date
# 0                    0            0           CAF  1992-12-31
# ...

# %%
#fifaFeatures = fifaRanks.drop(['cur_year_avg','cur_year_avg_weighted','last_year_avg','last_year_avg_weighted','two_year_ago_avg',
#                   'three_year_ago_avg', 'three_year_ago_weighted'], axis = 1)

# %%
#fifaFeatures
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 0         1      Germany          GER           0.0               57
# 1         2        Italy          ITA           0.0               57
# 2         3  Switzerland          SUI           0.0               50
# 3         4       Sweden          SWE           0.0               55
# 4         5    Argentina          ARG           0.0               51
# ...     ...          ...          ...           ...              ...
# 57788   206     Anguilla          AIA           0.0                0
# 57789   206      Bahamas          BAH           0.0                0
# 57790   206      Eritrea          ERI           0.0                0
# 57791   206      Somalia          SOM           0.0                0
# 57792   206        Tonga          TGA           0.0                0
#
#        rank_change  two_year_ago_weighted confederation   rank_date
# 0                0                    0.0          UEFA  1993-08-08
# ...

# %%
# convert date column into date format
fifaRanks['rank_date'] = pd.to_datetime(fifaRanks['rank_date'])
  
# filter rows on the basis of date
newdf = (fifaRanks['rank_date'] > '1992-12-31') & (fifaRanks['rank_date'] <= '2020-12-10')
  
# locate rows and access them using .loc() function
newdf = fifaRanks.loc[newdf]
  
# print dataframe
print(newdf)
# Out:
#             id  rank          country_full country_abrv  total_points  \
# 163      43970     4                Sweden          SWE            56
# 164      43825   108               Lebanon          LBN            11
# 165      43883   109          South Africa          RSA            11
# 166      43958   110            Luxembourg          LUX            11
# 167      43944   111         Faroe Islands          FRO            11
# ...        ...   ...                   ...          ...           ...
# 62419    43840    74  United Arab Emirates          UAE          1326
# 62420    43812    75              China PR          CHN          1323
# 62421  1930407    76               Curaçao          CUW          1313
# 62422    43901    51            Costa Rica          CRC          1427
# 62423    43966   210            San Marino          SMR           810
#
#        previous_points  rank_change confederation  rank_date
# 163                 56            0          UEFA 1993-08-08
# ...

# %%
newdf
# Out:
#             id  rank          country_full country_abrv  total_points  \
# 163      43970     4                Sweden          SWE            56
# 164      43825   108               Lebanon          LBN            11
# 165      43883   109          South Africa          RSA            11
# 166      43958   110            Luxembourg          LUX            11
# 167      43944   111         Faroe Islands          FRO            11
# ...        ...   ...                   ...          ...           ...
# 62419    43840    74  United Arab Emirates          UAE          1326
# 62420    43812    75              China PR          CHN          1323
# 62421  1930407    76               Curaçao          CUW          1313
# 62422    43901    51            Costa Rica          CRC          1427
# 62423    43966   210            San Marino          SMR           810
#
#        previous_points  rank_change confederation  rank_date
# 163                 56            0          UEFA 1993-08-08
# ...
